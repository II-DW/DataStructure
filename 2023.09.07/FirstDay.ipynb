# %%
print('My', 'Name', 'Is', 'Dowon Lee')
# Out:
# My Name Is Dowon Lee

# %%
print('My', 'Name', 'Is', 'Dowon Lee', sep = '! ')
# Out:
# My! Name! Is! Dowon Lee

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
print("pi =", pi)
# Out:
# pi = 3.14

# %%
print('Lee', 'Do', 'Won', sep = '*')
# Out:
# Lee*Do*Won

# %%
x:int = 5
y:float = 110.5

z:float = x + y

print('z =', z)
# Out:
# z = 115.5

# %%
x:int = (30 + 35) % 10
print(x)

print(20/3)

print(20//3)
# Out:
# 5
# 6.666666666666667
# 6

# %%
L:list = ['lion', 'in', 'oil']
print(L)

print("5's element")

print('5"s element')
# Out:
# ['lion', 'in', 'oil']
# 5's element
# 5"s element

# %%
a:int = 3
if a < 0 :
  print("a is N.number")
elif a > 0 :
  print("a is P.number")
else:
  print("a is zero")
# Out:
# a is P.number

# %%
number1:int = int(input())
number2:int = int(input())

print(number1 + number2)
# Out:
# 10
# 10
# 20

# %%
length:float = float(input())

if length < 170 :
  print(length, 'is smaller than teacher')
