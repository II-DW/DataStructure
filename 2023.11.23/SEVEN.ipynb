# %% [markdown]
# # 선택 정렬

# %% [markdown]
# 자료의 횟수가 미리 정해져 있음.

# %% [markdown]
# # 삽입 정렬

# %% [markdown]
# 알고리즘이 단순함.
# 데이터가 이미 정렬

# %% [markdown]
# # 버블 정렬

# %% [markdown]
# 구현이 매우 간단함.
# 다른 메모리 공간을 필요로 하지 않음.

# %% [markdown]
# 비효율적임.

# %% [markdown]
# # 퀵 정렬

# %% [markdown]
# # 병합 정렬
